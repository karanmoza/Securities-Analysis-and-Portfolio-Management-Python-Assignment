# %% [markdown]
# Group 3
#
# Harrshit Limbodia	2019B4A40815H
#
# Ninaad Pinakin Thakkar 	2019B4A40872H
#
# Gautam Gupta	2019B2A41118H
#
# Karan Moza	2019B4A71372H
#
# Khushi Khanna 	2019B4A10850H
#
# Aryaa Bharani	2019B1A11556H
#
# Arnav Bhatara	2019B4AA1304H
#
# Sankalp Bhadoria	2019B3AA1269H
#
# Abhimanyu Singh Rana	2019B3A80701H

# %% [markdown]
# Event: 8th November 2016 Demonetization

# %%
#Install required libraries
# !pip install yfinance
import matplotlib.pyplot as plt
import statsmodels.api as sm
import yfinance as yf
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as stats
import warnings
warnings.filterwarnings("ignore")

# %%
TataSteeldf = yf.download('TATASTEEL.NS', 
                      start='2015-12-16', 
                      end='2017-01-04', 
                      progress=False
)
TataSteeldf.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2015-12-16  234.897217  236.850327  230.657547  233.134659  183.701370
# 2015-12-17  235.230682  245.758423  234.420853  244.948593  193.010284
# 2015-12-18  244.376953  245.758423  241.995102  243.567123  191.921753
# 2015-12-21  243.424210  249.045364  242.614380  246.234787  194.023758
# 2015-12-22  246.758789  249.426453  244.424591  245.234406  193.235535
#
#               Volume
# Date
# 2015-12-16   6045633
# 2015-12-17  12713159
# 2015-12-18   7288697
# 2015-12-21   6502570
# 2015-12-22   4769687

# %%
nifty_df = yf.download('^NSEI',start='2015-12-16', 
                      end='2017-01-04', 
                      progress=False
)
nifty_df.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2015-12-16  7725.250000  7776.600098  7715.750000  7750.899902  7750.899902
# 2015-12-17  7783.049805  7852.899902  7737.549805  7844.350098  7844.350098
# 2015-12-18  7828.899902  7836.149902  7753.350098  7761.950195  7761.950195
# 2015-12-21  7745.649902  7840.750000  7733.450195  7834.450195  7834.450195
# 2015-12-22  7829.399902  7846.299805  7776.850098  7786.100098  7786.100098
#
#             Volume
# Date
# 2015-12-16  154300
# 2015-12-17  175900
# 2015-12-18  191400
# 2015-12-21  126300
# 2015-12-22  125700

# %%
#Calculate Log returns
nifty_df['Return_NIFTY'] = np.log(nifty_df['Adj Close']/nifty_df['Adj Close'].shift(1))
print(nifty_df['Return_NIFTY'])
# Out:
# Date
# 2015-12-16         NaN
# 2015-12-17    0.011985
# 2015-12-18   -0.010560
# 2015-12-21    0.009297
# 2015-12-22   -0.006191
#                 ...
# 2016-12-28    0.000249
# 2016-12-29    0.008520
# 2016-12-30    0.010093
# 2017-01-02   -0.000770
# 2017-01-03    0.001558
# Name: Return_NIFTY, Length: 257, dtype: float64

# %%
#removing one enties from NIFTY 50 data
nifty_df.dropna(inplace=True)

# %%
TataSteeldf['Return_TataSteel'] = np.log(TataSteeldf['Adj Close']/TataSteeldf['Adj Close'].shift(1))
print(TataSteeldf['Return_TataSteel'])
# Out:
# Date
# 2015-12-17         NaN
# 2015-12-18   -0.005656
# 2015-12-21    0.010893
# 2015-12-22   -0.004071
# 2015-12-23    0.027021
#                 ...
# 2016-12-28   -0.010117
# 2016-12-29    0.009990
# 2016-12-30   -0.002808
# 2017-01-02    0.038852
# 2017-01-03   -0.008518
# Name: Return_TataSteel, Length: 258, dtype: float64

# %%
#removing one enties from company data
TataSteeldf.dropna(inplace=True)

# %%
TataSteeldf
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2015-12-18  244.376953  245.758423  241.995102  243.567123  191.921753
# 2015-12-21  243.424210  249.045364  242.614380  246.234787  194.023758
# 2015-12-22  246.758789  249.426453  244.424591  245.234406  193.235535
# 2015-12-23  249.855179  253.809036  249.855179  251.951202  198.528107
# 2015-12-24  253.427948  253.427948  248.283173  250.903198  197.702301
# ...                ...         ...         ...         ...         ...
# 2016-12-28  374.758972  375.140045  368.232697  370.090546  298.188202
# 2016-12-29  370.138184  375.282959  368.947266  373.806213  301.182007
# 2016-12-30  374.425507  376.712067  369.757080  372.758209  300.337555
# 2017-01-02  374.854218  389.050018  370.519287  387.525635  312.235931
# 2017-01-03  387.811462  389.574005  382.285583  384.238678  309.587585
#
#              Volume  Return_TataSteel
# Date
# 2015-12-18  7288697         -0.005656
# ...

# %%
TataSteelreturns = TataSteeldf['Return_TataSteel']
TataSteelreturns.head()
# Out:
# Date
# 2015-12-18   -0.005656
# 2015-12-21    0.010893
# 2015-12-22   -0.004071
# 2015-12-23    0.027021
# 2015-12-24   -0.004168
# Name: Return_TataSteel, dtype: float64

# %%
niftyreturns = nifty_df['Return_NIFTY']
niftyreturns.head()
# Out:
# Date
# 2015-12-17    0.011985
# 2015-12-18   -0.010560
# 2015-12-21    0.009297
# 2015-12-22   -0.006191
# 2015-12-23    0.010203
# Name: Return_NIFTY, dtype: float64

# %%
#Combining the NIFTY 50 and Company returns 
returns = pd.merge(niftyreturns,TataSteelreturns,how='inner',on='Date')
returns.head()
# Out:
#             Return_NIFTY  Return_TataSteel
# Date
# 2015-12-18     -0.010560         -0.005656
# 2015-12-21      0.009297          0.010893
# 2015-12-22     -0.006191         -0.004071
# 2015-12-23      0.010203          0.027021
# 2015-12-24     -0.000623         -0.004168

# %%
returns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 255 entries, 2015-12-18 to 2017-01-03
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Return_NIFTY      255 non-null    float64
#  1   Return_TataSteel  255 non-null    float64
# dtypes: float64(2)
# memory usage: 6.0 KB

# %%
nifty_df.shape
# Out:
# (256, 7)

# %%
nifty_df
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2015-12-17  7783.049805  7852.899902  7737.549805  7844.350098  7844.350098
# 2015-12-18  7828.899902  7836.149902  7753.350098  7761.950195  7761.950195
# 2015-12-21  7745.649902  7840.750000  7733.450195  7834.450195  7834.450195
# 2015-12-22  7829.399902  7846.299805  7776.850098  7786.100098  7786.100098
# 2015-12-23  7830.450195  7871.450195  7826.100098  7865.950195  7865.950195
# ...                 ...          ...          ...          ...          ...
# 2016-12-28  8047.549805  8100.549805  8028.399902  8034.850098  8034.850098
# 2016-12-29  8030.600098  8111.100098  8020.799805  8103.600098  8103.600098
# 2016-12-30  8119.649902  8197.000000  8114.750000  8185.799805  8185.799805
# 2017-01-02  8210.099609  8212.000000  8133.799805  8179.500000  8179.500000
# 2017-01-03  8196.049805  8219.099609  8148.600098  8192.250000  8192.250000
#
#             Volume  Return_NIFTY
# Date
# ...

# %%
returns.shape
# Out:
# (255, 2)

# %% [markdown]
# Regression by Market Model

# %%
x = returns['Return_NIFTY']
y = returns['Return_TataSteel']
x_sm = sm.add_constant(x)

# %%
#Regression - Market model 
marketmodel = sm.OLS(y,x_sm)

# %%
resultsmm = marketmodel.fit()

# %%
resultsmm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           Return_ICICI   R-squared:                       0.464
# Model:                            OLS   Adj. R-squared:                  0.462
# Method:                 Least Squares   F-statistic:                     219.7
# Date:                Thu, 14 Jul 2022   Prob (F-statistic):           3.12e-36
# Time:                        13:33:51   Log-Likelihood:                 689.39
# No. Observations:                 256   AIC:                            -1375.
# Df Residuals:                     254   BIC:                            -1368.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
betaTataSteelmm=resultsmm.params[1]

# %%
resultsmm.f_pvalue
# Out:
# 5.590127657108638e-27

# %%
returnsTataSteel=returns

# %%
returnsTataSteel['ER_MM']=returnsTataSteel['Return_NIFTY']*betaTataSteelmm

# %%
returnsTataSteel
# Out:
#             Return_NIFTY  Return_TataSteel     ER_MM
# Date
# 2015-12-18     -0.010560         -0.005656 -0.017122
# 2015-12-21      0.009297          0.010893  0.015074
# 2015-12-22     -0.006191         -0.004071 -0.010037
# 2015-12-23      0.010203          0.027021  0.016544
# 2015-12-24     -0.000623         -0.004168 -0.001010
# ...                  ...               ...       ...
# 2016-12-28      0.000249         -0.010117  0.000404
# 2016-12-29      0.008520          0.009990  0.013815
# 2016-12-30      0.010093         -0.002808  0.016364
# 2017-01-02     -0.000770          0.038852 -0.001248
# 2017-01-03      0.001558         -0.008518  0.002525
#
# [255 rows x 3 columns]

# %% [markdown]
# Using CAPM

# %%
rfr=0.02/100

# %%
returnsTataSteel['Rm-Rf']=returnsTataSteel['Return_NIFTY']-rfr

# %%
x = returns['Rm-Rf']
y = returns['Return_TataSteel']
x_sm = sm.add_constant(x)

# %%
capmmodel = sm.OLS(y,x_sm)

# %%
resultscapm = capmmodel.fit()

# %%
resultscapm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       Return_TataSteel   R-squared:                       0.368
# Model:                            OLS   Adj. R-squared:                  0.365
# Method:                 Least Squares   F-statistic:                     147.0
# Date:                Thu, 14 Jul 2022   Prob (F-statistic):           5.59e-27
# Time:                        18:49:34   Log-Likelihood:                 634.69
# No. Observations:                 255   AIC:                            -1265.
# Df Residuals:                     253   BIC:                            -1258.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0019      0.001      1.481      0.140      -0.001       0.004
# ...

# %%
returnsTataSteel['ER_CAPM']=rfr+resultscapm.params[1]*returnsTataSteel['Rm-Rf']

# %%
returnsTataSteel
# Out:
#             Return_NIFTY  Return_TataSteel     ER_MM     Rm-Rf   ER_CAPM
# Date
# 2015-12-18     -0.010560         -0.005656 -0.017122 -0.010760 -0.017246
# 2015-12-21      0.009297          0.010893  0.015074  0.009097  0.014950
# 2015-12-22     -0.006191         -0.004071 -0.010037 -0.006391 -0.010162
# 2015-12-23      0.010203          0.027021  0.016544  0.010003  0.016419
# 2015-12-24     -0.000623         -0.004168 -0.001010 -0.000823 -0.001135
# ...                  ...               ...       ...       ...       ...
# 2016-12-28      0.000249         -0.010117  0.000404  0.000049  0.000279
# 2016-12-29      0.008520          0.009990  0.013815  0.008320  0.013690
# 2016-12-30      0.010093         -0.002808  0.016364  0.009893  0.016240
# 2017-01-02     -0.000770          0.038852 -0.001248 -0.000970 -0.001373
# 2017-01-03      0.001558         -0.008518  0.002525  0.001358  0.002401
#
# [255 rows x 5 columns]

# %% [markdown]
# FAMA 3

# %%
famadf=pd.read_csv("C:\\Users\\Gautam Gupta\\Desktop\\2021-03_FourFactors_and_Market_Returns_Daily_SurvivorshipBiasAdjusted.csv")

# %%
famadf.drop(260,inplace=True)

# %%
famadf.set_index('Date',inplace=True)

# %%
famadf
# Out:
#                  SMB       HML       WML        MF        RF  days to event
# Date
# 2015-12-16 -0.697017  0.386837 -0.357558  0.447390  0.028099           -220
# 2015-12-17 -0.102805  1.226592  0.346055  1.263357  0.028256           -219
# 2015-12-18  0.588487  0.073747  0.526803 -0.667976  0.028256           -218
# 2015-12-21  0.413700  0.855782 -0.658280  0.708558  0.028256           -217
# 2015-12-22  0.544714  0.488610  0.026780 -0.394539  0.028256           -216
# ...              ...       ...       ...       ...       ...            ...
# 2016-12-28  0.987619 -0.501282 -0.077401  0.278990  0.024186             35
# 2016-12-29 -0.609323  0.376913  0.296232  1.086604  0.024439             36
# 2016-12-30  0.292598  0.134040 -0.193442  0.984796  0.024439             37
# 2017-01-02  0.646568  1.114708  0.634339  0.842830  0.024439             38
# 2017-01-03  1.091910  0.168891  0.457422  0.466742  0.024439             39
#
# [260 rows x 6 columns]

# %%
returnsTataSteel
# Out:
#             Return_NIFTY  Return_TataSteel     ER_MM     Rm-Rf   ER_CAPM
# Date
# 2015-12-18     -0.010560         -0.005656 -0.017122 -0.010760 -0.017246
# 2015-12-21      0.009297          0.010893  0.015074  0.009097  0.014950
# 2015-12-22     -0.006191         -0.004071 -0.010037 -0.006391 -0.010162
# 2015-12-23      0.010203          0.027021  0.016544  0.010003  0.016419
# 2015-12-24     -0.000623         -0.004168 -0.001010 -0.000823 -0.001135
# ...                  ...               ...       ...       ...       ...
# 2016-12-28      0.000249         -0.010117  0.000404  0.000049  0.000279
# 2016-12-29      0.008520          0.009990  0.013815  0.008320  0.013690
# 2016-12-30      0.010093         -0.002808  0.016364  0.009893  0.016240
# 2017-01-02     -0.000770          0.038852 -0.001248 -0.000970 -0.001373
# 2017-01-03      0.001558         -0.008518  0.002525  0.001358  0.002401
#
# [255 rows x 5 columns]

# %%
returnsTataSteel.index
# Out:
# DatetimeIndex(['2015-12-18', '2015-12-21', '2015-12-22', '2015-12-23',
#                '2015-12-24', '2015-12-28', '2015-12-29', '2015-12-30',
#                '2015-12-31', '2016-01-04',
#                ...
#                '2016-12-21', '2016-12-22', '2016-12-23', '2016-12-26',
#                '2016-12-27', '2016-12-28', '2016-12-29', '2016-12-30',
#                '2017-01-02', '2017-01-03'],
#               dtype='datetime64[ns]', name='Date', length=255, freq=None)

# %%
famadf.index=pd.to_datetime(famadf.index)

# %%
famadf.index
# Out:
# DatetimeIndex(['2015-12-16', '2015-12-17', '2015-12-18', '2015-12-21',
#                '2015-12-22', '2015-12-23', '2015-12-24', '2015-12-28',
#                '2015-12-29', '2015-12-30',
#                ...
#                '2016-12-21', '2016-12-22', '2016-12-23', '2016-12-26',
#                '2016-12-27', '2016-12-28', '2016-12-29', '2016-12-30',
#                '2017-01-02', '2017-01-03'],
#               dtype='datetime64[ns]', name='Date', length=260, freq=None)

# %%
returnsTataSteel=returnsTataSteel.join(famadf)

# %%
returnsTataSteel
# Out:
#             Return_NIFTY  Return_TataSteel     ER_MM     Rm-Rf   ER_CAPM  \
# Date
# 2015-12-18     -0.010560         -0.005656 -0.017122 -0.010760 -0.017246
# 2015-12-21      0.009297          0.010893  0.015074  0.009097  0.014950
# 2015-12-22     -0.006191         -0.004071 -0.010037 -0.006391 -0.010162
# 2015-12-23      0.010203          0.027021  0.016544  0.010003  0.016419
# 2015-12-24     -0.000623         -0.004168 -0.001010 -0.000823 -0.001135
# ...                  ...               ...       ...       ...       ...
# 2016-12-28      0.000249         -0.010117  0.000404  0.000049  0.000279
# 2016-12-29      0.008520          0.009990  0.013815  0.008320  0.013690
# 2016-12-30      0.010093         -0.002808  0.016364  0.009893  0.016240
# 2017-01-02     -0.000770          0.038852 -0.001248 -0.000970 -0.001373
# 2017-01-03      0.001558         -0.008518  0.002525  0.001358  0.002401
#
#                  SMB       HML       WML        MF        RF  days to event
# Date
# ...

# %%
X=returnsTataSteel[['Rm-Rf','SMB','HML']]
y=returnsTataSteel['Return_TataSteel']
X = sm.add_constant(X)

# %%
ff3=sm.OLS(y,X)

# %%
resultsff3=ff3.fit()

# %%
resultsff3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           Return_ICICI   R-squared:                       0.474
# Model:                            OLS   Adj. R-squared:                  0.467
# Method:                 Least Squares   F-statistic:                     75.62
# Date:                Thu, 14 Jul 2022   Prob (F-statistic):           6.50e-35
# Time:                        13:52:48   Log-Likelihood:                 691.80
# No. Observations:                 256   AIC:                            -1376.
# Df Residuals:                     252   BIC:                            -1361.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -6.347e-05      0.001     -0.062      0.951      -0.002       0.002
# ...

# %%
resultsff3.params[3]
# Out:
# 0.01595449163161463

# %%
returnsTataSteel['ER_ff3']=rfr+resultsff3.params[1]*returnsTataSteel['Rm-Rf']+resultsff3.params[3]*returnsTataSteel['HML']

# %% [markdown]
# FAMA FRENCH 4

# %%
X=returnsTataSteel[['Rm-Rf','SMB','HML','MF']]
y=returnsTataSteel['Return_TataSteel']
X = sm.add_constant(X)

# %%
ff4=sm.OLS(y,X)
resultsff4=ff4.fit()
resultsff4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       Return_TataSteel   R-squared:                       0.752
# Model:                            OLS   Adj. R-squared:                  0.749
# Method:                 Least Squares   F-statistic:                     190.0
# Date:                Thu, 14 Jul 2022   Prob (F-statistic):           1.51e-74
# Time:                        19:33:41   Log-Likelihood:                 754.31
# No. Observations:                 255   AIC:                            -1499.
# Df Residuals:                     250   BIC:                            -1481.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0009      0.001      1.134      0.258      -0.001       0.002
# ...

# %%
returnsTataSteel['ER_ff4']=rfr+resultsff4.params[1]*returnsTataSteel['Rm-Rf']+resultsff4.params[3]*returnsTataSteel['SMB']+resultsff4.params[3]*returnsTataSteel['HML']

# %%
returnsTataSteel
# Out:
#             Return_NIFTY  Return_TataSteel     ER_MM     Rm-Rf   ER_CAPM  \
# Date
# 2015-12-18     -0.010560         -0.005656 -0.017122 -0.010760 -0.017246
# 2015-12-21      0.009297          0.010893  0.015074  0.009097  0.014950
# 2015-12-22     -0.006191         -0.004071 -0.010037 -0.006391 -0.010162
# 2015-12-23      0.010203          0.027021  0.016544  0.010003  0.016419
# 2015-12-24     -0.000623         -0.004168 -0.001010 -0.000823 -0.001135
# ...                  ...               ...       ...       ...       ...
# 2016-12-28      0.000249         -0.010117  0.000404  0.000049  0.000279
# 2016-12-29      0.008520          0.009990  0.013815  0.008320  0.013690
# 2016-12-30      0.010093         -0.002808  0.016364  0.009893  0.016240
# 2017-01-02     -0.000770          0.038852 -0.001248 -0.000970 -0.001373
# 2017-01-03      0.001558         -0.008518  0.002525  0.001358  0.002401
#
#                  SMB       HML       WML        MF        RF  days to event  \
# Date
# ...

# %%
returnsTataSteel['AR_MM']=returnsTataSteel['Return_TataSteel']-returnsTataSteel['ER_MM']

# %%
returnsTataSteel['AR_CAPM']=returnsTataSteel['Return_TataSteel']-returnsTataSteel['ER_CAPM']

# %%
returnsTataSteel['AR_ff3']=returnsTataSteel['Return_TataSteel']-returnsTataSteel['ER_ff3']

# %%
returnsTataSteel['AR_ff4']=returnsTataSteel['Return_TataSteel']-returnsTataSteel['ER_ff4']

# %%
returnsTataSteel
# Out:
#             Return_NIFTY  Return_TataSteel     ER_MM     Rm-Rf   ER_CAPM  \
# Date
# 2015-12-18     -0.010560         -0.005656 -0.017122 -0.010760 -0.017246
# 2015-12-21      0.009297          0.010893  0.015074  0.009097  0.014950
# 2015-12-22     -0.006191         -0.004071 -0.010037 -0.006391 -0.010162
# 2015-12-23      0.010203          0.027021  0.016544  0.010003  0.016419
# 2015-12-24     -0.000623         -0.004168 -0.001010 -0.000823 -0.001135
# ...                  ...               ...       ...       ...       ...
# 2016-12-28      0.000249         -0.010117  0.000404  0.000049  0.000279
# 2016-12-29      0.008520          0.009990  0.013815  0.008320  0.013690
# 2016-12-30      0.010093         -0.002808  0.016364  0.009893  0.016240
# 2017-01-02     -0.000770          0.038852 -0.001248 -0.000970 -0.001373
# 2017-01-03      0.001558         -0.008518  0.002525  0.001358  0.002401
#
#                  SMB       HML       WML        MF        RF  days to event  \
# Date
# ...

# %%
returnsTataSteel_eventwindowbeyond=returnsTataSteel[returnsTataSteel['days to event']>=-20]

# %%
returnsTataSteel_eventwindowbeyond
# Out:
#             Return_NIFTY  Return_TataSteel     ER_MM     Rm-Rf   ER_CAPM  \
# Date
# 2016-10-07     -0.001373          0.041945 -0.002226 -0.001573 -0.002351
# 2016-10-10      0.001287          0.028731  0.002087  0.001087  0.001962
# 2016-10-13     -0.015675         -0.011055 -0.025416 -0.015875 -0.025541
# 2016-10-14      0.001172         -0.003631  0.001900  0.000972  0.001775
# 2016-10-17     -0.007367         -0.003645 -0.011945 -0.007567 -0.012069
# 2016-10-18      0.018316          0.033865  0.029698  0.018116  0.029574
# 2016-10-19     -0.002169          0.002468 -0.003517 -0.002369 -0.003641
# 2016-10-20      0.004643          0.005968  0.007529  0.004443  0.007404
# 2016-10-21     -0.000730         -0.003155 -0.001184 -0.000930 -0.001308
# 2016-10-24      0.001827         -0.002695  0.002963  0.001627  0.002839
# 2016-10-25     -0.002029         -0.025676 -0.003289 -0.002229 -0.003414
# 2016-10-26     -0.008789         -0.040922 -0.014250 -0.008989 -0.014374
# ...

# %%
returnsTataSteel_eventwindowbeyond['CAR_MM']=returnsTataSteel_eventwindowbeyond['AR_MM'].cumsum()

# %%
returnsTataSteel_eventwindowbeyond['CAR_CAPM']=returnsTataSteel_eventwindowbeyond['AR_CAPM'].cumsum()

# %%
returnsTataSteel_eventwindowbeyond['CAR_ff3']=returnsTataSteel_eventwindowbeyond['AR_ff3'].cumsum()

# %%
returnsTataSteel_eventwindowbeyond['CAR_ff4']=returnsTataSteel_eventwindowbeyond['AR_ff4'].cumsum()

# %%
returnsTataSteel_eventwindowbeyond
# Out:
#             Return_NIFTY  Return_TataSteel     ER_MM     Rm-Rf   ER_CAPM  \
# Date
# 2016-10-07     -0.001373          0.041945 -0.002226 -0.001573 -0.002351
# 2016-10-10      0.001287          0.028731  0.002087  0.001087  0.001962
# 2016-10-13     -0.015675         -0.011055 -0.025416 -0.015875 -0.025541
# 2016-10-14      0.001172         -0.003631  0.001900  0.000972  0.001775
# 2016-10-17     -0.007367         -0.003645 -0.011945 -0.007567 -0.012069
# 2016-10-18      0.018316          0.033865  0.029698  0.018116  0.029574
# 2016-10-19     -0.002169          0.002468 -0.003517 -0.002369 -0.003641
# 2016-10-20      0.004643          0.005968  0.007529  0.004443  0.007404
# 2016-10-21     -0.000730         -0.003155 -0.001184 -0.000930 -0.001308
# 2016-10-24      0.001827         -0.002695  0.002963  0.001627  0.002839
# 2016-10-25     -0.002029         -0.025676 -0.003289 -0.002229 -0.003414
# 2016-10-26     -0.008789         -0.040922 -0.014250 -0.008989 -0.014374
# ...

# %%
returnsTataSteel
# Out:
#             Return_NIFTY  Return_TataSteel     ER_MM     Rm-Rf   ER_CAPM  \
# Date
# 2015-12-18     -0.010560         -0.005656 -0.017122 -0.010760 -0.017246
# 2015-12-21      0.009297          0.010893  0.015074  0.009097  0.014950
# 2015-12-22     -0.006191         -0.004071 -0.010037 -0.006391 -0.010162
# 2015-12-23      0.010203          0.027021  0.016544  0.010003  0.016419
# 2015-12-24     -0.000623         -0.004168 -0.001010 -0.000823 -0.001135
# ...                  ...               ...       ...       ...       ...
# 2016-12-28      0.000249         -0.010117  0.000404  0.000049  0.000279
# 2016-12-29      0.008520          0.009990  0.013815  0.008320  0.013690
# 2016-12-30      0.010093         -0.002808  0.016364  0.009893  0.016240
# 2017-01-02     -0.000770          0.038852 -0.001248 -0.000970 -0.001373
# 2017-01-03      0.001558         -0.008518  0.002525  0.001358  0.002401
#
#                  SMB       HML       WML        MF        RF  days to event  \
# Date
# ...

# %%
returnsTataSteel_eventwindowbeyond[['Return_TataSteel','CAR_MM']]
# Out:
#             Return_TataSteel    CAR_MM
# Date
# 2016-10-07          0.041945  0.044171
# 2016-10-10          0.028731  0.070815
# 2016-10-13         -0.011055  0.085177
# 2016-10-14         -0.003631  0.079645
# 2016-10-17         -0.003645  0.087945
# 2016-10-18          0.033865  0.092112
# 2016-10-19          0.002468  0.098097
# 2016-10-20          0.005968  0.096536
# 2016-10-21         -0.003155  0.094565
# 2016-10-24         -0.002695  0.088906
# 2016-10-25         -0.025676  0.066520
# 2016-10-26         -0.040922  0.039847
# 2016-10-27         -0.003644  0.036203
# 2016-10-28          0.020684  0.052610
# 2016-11-01          0.029766  0.084583
# 2016-11-02         -0.010469  0.095352
# 2016-11-03         -0.024614  0.076280
# 2016-11-04         -0.000496  0.085597
# 2016-11-07          0.023294  0.096767
# 2016-11-08         -0.009620  0.078298
# 2016-11-09         -0.023021  0.076587
# 2016-11-10          0.090095  0.148754
# 2016-11-11         -0.024321  0.168668
# ...

# %%
returnsTataSteelfinal=returnsTataSteel.join(returnsTataSteel_eventwindowbeyond[['CAR_MM','CAR_CAPM','CAR_ff3','CAR_ff4']],on='Date',how='left')

# %%
returnsTataSteelfinal.columns
# Out:
# Index(['Return_NIFTY', 'Return_TataSteel', 'ER_MM', 'Rm-Rf', 'ER_CAPM', 'SMB',
#        'HML', 'WML', 'MF', 'RF', 'days to event', 'ER_ff3', 'AR_MM', 'AR_CAPM',
#        'AR_ff3', 'ER_ff4', 'AR_ff4', 'CAR_MM', 'CAR_CAPM', 'CAR_ff3',
#        'CAR_ff4'],
#       dtype='object')

# %%
#final data with all AR, CAR, factors of APM and expected returns acc. to diff. models
returnsTataSteelfinal
# Out:
#             Return_NIFTY  Return_TataSteel     ER_MM     Rm-Rf   ER_CAPM  \
# Date
# 2015-12-18     -0.010560         -0.005656 -0.017122 -0.010760 -0.017246
# 2015-12-21      0.009297          0.010893  0.015074  0.009097  0.014950
# 2015-12-22     -0.006191         -0.004071 -0.010037 -0.006391 -0.010162
# 2015-12-23      0.010203          0.027021  0.016544  0.010003  0.016419
# 2015-12-24     -0.000623         -0.004168 -0.001010 -0.000823 -0.001135
# ...                  ...               ...       ...       ...       ...
# 2016-12-28      0.000249         -0.010117  0.000404  0.000049  0.000279
# 2016-12-29      0.008520          0.009990  0.013815  0.008320  0.013690
# 2016-12-30      0.010093         -0.002808  0.016364  0.009893  0.016240
# 2017-01-02     -0.000770          0.038852 -0.001248 -0.000970 -0.001373
# 2017-01-03      0.001558         -0.008518  0.002525  0.001358  0.002401
#
#                  SMB       HML       WML        MF        RF  ...    ER_ff3  \
# ...

# %% [markdown]
# Description of various factors used in above APM
#
# - Market Model:-In the CAPM model, we use the risk premium as the independent variable and the actual returns of the security as the dependent variable for the regression.
#
# - CAPM:-For the market index model, we use the actual return of the index as the independent variable and the actual returns of the security as the dependent variable for the regression.
#
# - FF3:-For Fama 3 factor model, we defined big firms (B) as the top 10% by market capitalization and classified the remaining firms as small firms (S), Growth stocks (low value group), G, comprised the bottom 30% stocks in terms of the B/M ratio.The remaining stocks were grouped as neutral (N) stocks, the value factor HML (High minus Low) is defined as the simple average of two differences: (Small Value companies - Small Growth companies) and (Big value companies - Big growth companies), the value factor SMB (Small minus Big) is the simple average of three return differences: (Small Growth companies − Big growth companies), (Small neutral companies − Big Neutral companies) and (Small Value companies − Big value companies) High value group, V , consisted of the top 30% stocks in terms of the B/M ratio. The third factor being the market risk premium to compute beta via regression.
#
#
# - FF4:-For Fama 4 factor model, we used HML, SMB and market risk premium as in the 3 factor model and in additon, the momentum factor MF for the regression to find beta.

# %% [markdown]
# Plotting graphs (CAR vs Days Rel. to Event)

# %%
returnsTataSteelfinal.plot(x='days to event', y='CAR_MM',figsize=(8,5))
# Out:
# <AxesSubplot:xlabel='days to event'>

# %%
returnsTataSteelfinal.plot(x='days to event', y='CAR_CAPM',figsize=(8,5))
# Out:
# <AxesSubplot:xlabel='days to event'>

# %%
returnsTataSteelfinal.plot(x='days to event', y='CAR_ff3',figsize=(8,5))
# Out:
# <AxesSubplot:xlabel='days to event'>

# %%
returnsTataSteelfinal.plot(x='days to event', y='CAR_ff4',figsize=(8,5))
# Out:
# <AxesSubplot:xlabel='days to event'>

# %% [markdown]
# Final Conclusions (Interpretation of above Graphs)
#
# - Market Model:-The figure suggests that the capital market perceives this event to be favorable for this particular security as there was some correction before the event, but on the event-day graph reverses its trajectory and shows a positive trend.
#
# - CAPM:-The figure suggests that the capital market perceives this event to be favorable for this particular security as there was some correction before the event, but on the event-day graph reverses its trajectory and shows a positive trend.
#
#
# - FF3:-As we look from -20 to -10 days, there was a prominent downward trend in the prices, but on the events, day prices started to show a positive trend. The figure suggests that the capital market perceives this event as favorable for this particular security. But this trend is short-lived, and price goes down even further after a few days of the event
#
# - FF4:-From all the graph above, this figure shows a more prominent positive trend; therefore capital market perceives this event to be favorable for this particular security, and the positive trend last significantly for more time than other models
